# %%
import os

# %%
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
# ...

# %%
len(dir(os))
# Out:
# 156

# %%
os.getcwd()
# Out:
# 'c:\\Users\\mohan\\AppData\\Local\\Programs\\Microsoft VS Code'

# %%
#os.chdir("c:\\Users\\mohan\\AppData\\Local\\Programs\\Microsoft VS Code")

# %%
os.mkdir("folder path")
os.makedirs("multiple level of folder path")

os.rmdir()
os.removedirs("delete all the levels")

# %%
os.listdir("c:\\Users\\mohan\\AppData\\Local\\Programs")
# Out:
# ['Common', 'Microsoft VS Code']

# %%
os.rename("originalfilenaem.py","newfilename.py")  # with extensions

# %%
for dirpath, folderpath, filepath in os.walk("c:\\Users\\mohan\\AppData\\Local\\Programs\\Microsoft VS Code"):
    print("Dir path",dirpath)
    print("Folders",folderpath)
    print("files", filepath)
# Out:
# Dir path c:\Users\mohan\AppData\Local\Programs\Microsoft VS Code
# Folders ['bin', 'locales', 'policies', 'resources', 'tools', '_']
# files ['chrome_100_percent.pak', 'chrome_200_percent.pak', 'Code.exe', 'Code.VisualElementsManifest.xml', 'd3dcompiler_47.dll', 'ffmpeg.dll', 'icudtl.dat', 'libEGL.dll', 'libGLESv2.dll', 'LICENSES.chromium.html', 'resources.pak', 'snapshot_blob.bin', 'unins000.dat', 'unins000.exe', 'unins000.msg', 'v8_context_snapshot.bin', 'vk_swiftshader.dll', 'vk_swiftshader_icd.json', 'vulkan-1.dll']
# Dir path c:\Users\mohan\AppData\Local\Programs\Microsoft VS Code\bin
# Folders []
# files ['code', 'code-tunnel.exe', 'code.cmd']
# Dir path c:\Users\mohan\AppData\Local\Programs\Microsoft VS Code\locales
# Folders []
# ...
